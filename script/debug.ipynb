# %%
# %run run_test
# Out:
# self.device is cuda:0
# 6
#
#
#
#  # --- Validation Set --- #
#
#
#
# plateBBox = [3, 4, 397, 360]
# imgIDs = ['0065']
# center=[[129 124 109]
#  [ 11  51  94]]
# center=[[ 12  46  85]
#  [136 129 113]]
# /home/nansong/Dropbox/collaborative_ws/net_ws/src/pytorch_pix2food/src/pytorch_pix2food/metric.py:13: RuntimeWarning: invalid value encountered in long_scalars
#   pixAccuracy = (n_00 + n_11) / (t_0 + t_1)
# /home/nansong/Dropbox/collaborative_ws/net_ws/src/pytorch_pix2food/src/pytorch_pix2food/metric.py:14: RuntimeWarning: invalid value encountered in long_scalars
#   meanAccurracy = ((n_00 / t_0) + (n_11 / t_1)) / 2
# /home/nansong/Dropbox/collaborative_ws/net_ws/src/pytorch_pix2food/src/pytorch_pix2food/metric.py:26: RuntimeWarning: invalid value encountered in long_scalars
#   meanIoU = (i_0 / u_0 + i_1 / u_1) / 2
# pixAcurracy = nan, meanAccuracy = nan, meanIoU = nan
# plateBBox = [3, 2, 398, 362]
# imgIDs = ['0062']
# center=[[126 122 109]
#  [  8  48  92]]
# ...
